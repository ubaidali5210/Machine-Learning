# %% [markdown]
# ## import library

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../Data/Algerian_forest_fires_dataset_UPDATE.csv', header=1)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
# dtypes: str(14)
# memory usage: 27.0 KB

# %% [markdown]
# ## data cleaning

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
#  14  Region       246 non-null    float64
# dtypes: float64(1), str(14)
# memory usage: 29.0 KB

# %%
df[['Region']]=df[["Region"]].astype(int)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %% [markdown]
# ## removing the null values

# %%
df=df.dropna().reset_index(drop=True)
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %% [markdown]
# ## remove the 122nd row

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='str')

# %% [markdown]
# ## fix spaces in columns names

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    str
#  1   month        243 non-null    str
#  2   year         243 non-null    str
#  3   Temperature  243 non-null    str
#  4   RH           243 non-null    str
#  5   Ws           243 non-null    str
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(1), str(14)
# memory usage: 28.6 KB

# %% [markdown]
# ## changes the required columns as integer data type

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']]=df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(7), str(8)
# memory usage: 28.6 KB

# %%
df = df.drop(122)

# %% [markdown]
# ## changing the other columns to float data datatype

# %%
object = [features for features in df.columns if df[features].dtype == 'str']

for i in object:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 242 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    str
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), str(1)
# memory usage: 30.2 KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  242.000000  242.000000   242.0   242.000000  242.000000  242.000000
# mean    15.822314    7.508264  2012.0    32.152893   62.004132   15.508264
# std      8.809501    1.112888     0.0     3.635545   14.847635    2.808171
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.250000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.750000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  242.000000  242.000000  242.000000  242.000000  242.000000  242.000000
# mean     0.763223   77.928099   14.730992   49.601240    4.759504   16.747934
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %% [markdown]
# content = """# Machine Learning Workflow Revision: Algerian Forest Fires FWI Prediction
#
# ### 1. Setup and Data Loading
# * **Imported Libraries:** Loaded `pandas` for data manipulation, `numpy` for numerical operations, and `matplotlib`/`seaborn` for data visualization.
# * **Loaded Data:** Ingested the dataset `Algerian_forest_fires_cleaned_dataset.csv` into a pandas DataFrame and inspected the first few rows and column names.
#
# ### 2. Data Cleaning and Preprocessing
# * **Dropped Unnecessary Columns:** Removed the `day`, `month`, and `year` columns as they are temporal features not relevant to the specific weather-based prediction task.
# * **Encoded Categorical Data:** Checked the unique values in the `Classes` column. Recognizing that it contained string values (with some inconsistent spacing), used `np.where` combined with `str.contains("not fire")` to encode it into binary format: **0** for "not fire" and **1** for "fire".
#
# ### 3. Feature Separation and Train-Test Split
# * **Defined X and y:** Isolated the target variable, `FWI` (Fire Weather Index), setting it as `y`. The remaining columns were set as the independent features, `X`.
# * **Data Splitting:** Used `train_test_split` to divide the data into training (75%) and testing (25%) sets, ensuring the model can be evaluated on unseen data.
#
# ### 4. Multicollinearity Check (Feature Selection)
# * **Correlation Matrix & Heatmap:** Generated a correlation matrix for the training data and visualized it using a Seaborn heatmap to identify highly correlated features.
# * **Removed Redundant Features:** Wrote a custom function to find features with a correlation higher than **0.85**. Dropped these highly correlated features from both the training and testing sets to prevent multicollinearity (which can skew regression coefficients).
#
# ### 5. Feature Scaling
# * **Standardization:** Applied `StandardScaler` to normalize the range of the independent variables. Fit and transformed the training set, and only transformed the testing set to prevent data leakage.
# * **Visual Verification:** Plotted boxplots comparing the `X_train` data before and after scaling to visually confirm that the data distribution was centered around zero.
#
# ### 6. Model Building and Evaluation
# Systematically trained and evaluated four different types of regression models, calculating the Mean Absolute Error (MAE) and R2 Score for each, alongside plotting the actual vs. predicted values.
# * **Multiple Linear Regression:** Baseline model achieved an impressive R2 score of **~0.984**.
# * **Lasso Regression (L1 Regularization):** Tested Lasso, which helps with feature selection by shrinking some coefficients to zero. The baseline Lasso model performed slightly worse (R2 **~0.949**).
# * **Ridge Regression (L2 Regularization):** Tested Ridge, which penalizes large coefficients. It performed very similarly to standard Linear Regression (R2 **~0.984**).
# * **ElasticNet Regression (L1 + L2 Regularization):** Tested ElasticNet, which combines Lasso and Ridge penalties. The baseline model had an R2 of **~0.875**.
#
# ### 7. Cross-Validation and Hyperparameter Tuning
# To optimize the regularized models, utilized Cross-Validation (CV) versions of the algorithms with 5 folds (`cv=5`). This automatically searches for the best penalty parameter (alpha).
# * **LassoCV:** Found the optimal alpha to improve the Lasso model's R2 score to **~0.982**.
# * **RidgeCV:** Maintained a strong R2 score of **~0.984**.
# * **ElasticNetCV:** Found the optimal alpha to vastly improve the ElasticNet model's R2 score from **0.875** to **~0.981**.
# """
#
# file_path = "/mnt/data/ML_Workflow_Revision.md"
# with open(file_path, "w") as f:
#     f.write(content)
#
# print(f"File saved to {file_path}")

# %% [markdown]
# ## clean the dataset

# %%
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv', index=False)

# %% [markdown]
# # exploratory data analysis

# %%
df_copy = df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## categories in classes

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         100
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %% [markdown]
# ## encoding of the categories in classes

# %%
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    105
# Name: count, dtype: int64

# %% [markdown]
# ## plot density plot for all features

# %%
plt.style.use('seaborn-v0_8')
df_copy.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ## percentage for pie chart

# %%
percentage = df_copy['Classes'].value_counts(normalize=True)*100

# %% [markdown]
# # plotting piechart

# %%
classlabels=['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title('Pie Chart of Classes')
plt.show()

# %% [markdown]
# ## correlation

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651791 -0.285644 -0.326499  0.679270  0.486494
# RH             -0.651791  1.000000  0.248148  0.222604 -0.644536 -0.407180
# Ws             -0.285644  0.248148  1.000000  0.171896 -0.175324 -0.005819
# Rain           -0.326499  0.222604  0.171896  1.000000 -0.546470 -0.289482
# FFMC            0.679270 -0.644536 -0.175324 -0.546470  1.000000  0.601527
# DMC             0.486494 -0.407180 -0.005819 -0.289482  0.601527  1.000000
# DC              0.376720 -0.225293  0.075031 -0.298600  0.505185  0.875511
# ISI             0.604948 -0.686103  0.003408 -0.348334  0.738754  0.679150
# BUI             0.460533 -0.352357  0.026542 -0.300574  0.589881  0.982178
# FWI             0.567506 -0.580109  0.027768 -0.325112  0.689822  0.875405
# Classes         0.517203 -0.430794 -0.076262 -0.380263  0.768069  0.583760
# ...

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr())
# Out:
# <Axes: >

# %% [markdown]
# ## box plot

# %%
sns.boxplot(df['FWI'],color="green")
# Out:
# <Axes: ylabel='FWI'>

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %% [markdown]
# ## monthly fire analysis

# %%
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('number of fires',weight='bold')
plt.xlabel('Month',weight='bold')
plt.title('Fire distribution across months in region 1',weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire distribution across months in region 1')

# %% [markdown]
# # monthly fire analysis

# %%
dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('number of fires',weight='bold')
plt.xlabel('Month',weight='bold')
plt.title('Fire distribution across months in region 0',weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire distribution across months in region 0')

# %% [markdown]
# Its observed that August and September had the most number of forest fires for both regions. And from the above plot of months, we can understand few things
#
# Most of the fires happened in August and very high Fires happened in only 3 months - June, July and August.
#
# Less Fires was on September
